# %%
import random

ans_dict = {'paper rock':'paper', 'paper scissors':'scissors', 'rock paper':'paper', 'scissors paper':'scissors', 'scissors rock':'rock', 'rock scissors':'rock'}
g = 0
w = 0
r = 0
s = 0
p = 0

def battle_decision(ans_dict, result, human, comp):
    """See the human and computer inputs and declare the winner."""
    if ans_dict[result] == human:
        print '\n Computer: ' + comp
        print ' You: ' + human +'\n'
        #print 'Outcome: You won this time'
    else:
        print '\n Computer: ' + comp
        print ' You: ' + human +'\n'
        #print 'Outcome: Computer won this time'   

rint = random.randint(0, 2)
choice = ['rock', 'paper', 'scissors']

while True:
    human = str(raw_input('Please enter Rock, Paper, Scissors or Quit: ')).lower()
    if g == 0:
        comp = choice[rint] 
    else:
        if r==s and r>p:
            comp = choice[0]
        elif r==p and r>s:
            comp = choice[1]
        elif p==s and s>r:
            comp = choice[2]    
        elif max(r,s,p) == r:
            comp = choice[1] 
        elif max(r,s,p) == s:  
            comp = choice[0] 
        elif max(r,s,p) == p:
            comp = choice[2] 
        else:
            comp = choice[rint]

    while True: 
        if human == 'rock':
            g = g +1
            r = r +1
            break
        elif human == 'paper':
            g = g +1
            p = p +1
            break
        elif human == 'scissors':
            g = g +1
            s = s +1
            break
        elif human == 'quit':
            break
        else:
            human = str(raw_input('Try again, please enter Rock, Paper, Scissors or Quit: ')).lower()
            True
    
    if human == 'quit':
        print '\n Thanks for playing ' + str(g) + ' games.'
        print ' You won ' + str(w) + ' times. Way to go! \n'
        break
    elif comp == human:
        print '\n Computer: ' + comp
        print ' You: ' + human 
        print ' Outcome: Draw \n'
        True
    else:  
        battle = comp + ' ' + human
        battle_decision(ans_dict, battle, human, comp)
        if ans_dict[battle] == human:
            w = w +1
        else: 
            w
        True
# Out:
# Please enter Rock, Paper, Scissors or Quit: r
# Try again, please enter Rock, Paper, Scissors or Quit: rock
#
#  Computer: paper
#  You: rock
#
# Please enter Rock, Paper, Scissors or Quit: paper
#
#  Computer: paper
#  You: paper
#  Outcome: Draw
#
# Please enter Rock, Paper, Scissors or Quit: paper
#
#  Computer: paper
#  You: paper
#  Outcome: Draw
#
# Please enter Rock, Paper, Scissors or Quit: scissors
#
#  Computer: scissors
#  You: scissors
#  Outcome: Draw
#
# Please enter Rock, Paper, Scissors or Quit: rock
#
#  Computer: scissors
#  You: rock
#
# Please enter Rock, Paper, Scissors or Quit: scissors
#
#  Computer: paper
#  You: scissors
#
# Please enter Rock, Paper, Scissors or Quit: rock
#
#  Computer: paper
#  You: rock
#
# Please enter Rock, Paper, Scissors or Quit: quit
#
#  Thanks for playing 7 games.
#  You won 2 times. Way to go!
